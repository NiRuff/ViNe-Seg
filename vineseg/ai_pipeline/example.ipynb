# %%
from vine_seg.utils import \
    predict, \
    get_vineseg_list

# %%
image_path = 'data/allen/yolo/train/images/1120246770.png'
model_path = 'models/vine_seg-all.pt'
prediction_result = predict(image_path, model_path, plot_first=True)

vineseg_list = get_vineseg_list(prediction_result)
# vineseg_list:
# [
#     {
#         'img_path': <str>,
#         'label': 'neuron' | 'neuron_too_small' | 'neuron_too_big'
#         'score': <float>,
#         'points': <array<float>>,
#     }, ...
# ]
# Out:
# image 1/1 /home/jonasm/work/vine-seg_segmentation/data/allen/yolo/train/images/1120246770.png: 640x640 69 cells, 19.6ms
# Speed: 1.5ms preprocess, 19.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
